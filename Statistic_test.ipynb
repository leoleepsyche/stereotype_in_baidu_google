# %%
import pandas as pd
import statsmodels.api as sm

# Load the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "DuckDuckGo": '../data/temp/modified_duckduckgo_follow_query.csv',
    "Google": '../data/temp/modified_google_follow_query.csv',
    "Yahoo": '../data/temp/modified_yahoo_follow_query.csv'
}


dfs = {}

# Process each file
for engine, path in file_paths.items():
    df = pd.read_csv(path)
    # Convert 'common_sentiment_rating' to numeric, treating non-numeric as NaN
    df['common_sentiment_rating'] = pd.to_numeric(df['common_sentiment_rating'], errors='coerce')
    dfs[engine] = df

# Function to compare Baidu Template 1 with other search engines for each category using Chi-square test
def compare_baidu_template_1(dfs):
    baidu_engine = "Baidu Template 1"
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    results = {}
    categories = set(dfs[baidu_engine]['category'].dropna())

    for category in categories:
        baidu_df = dfs[baidu_engine][dfs[baidu_engine]['category'] == category]

        for other_engine in other_engines:
            other_df = dfs[other_engine][dfs[other_engine]['category'] == category]

            # Count negative sentiment (common_sentiment_rating == 3) and others
            count_negative_baidu = baidu_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_df['common_sentiment_rating'].count() - count_negative_baidu

            count_negative_other = other_df['common_sentiment_rating'].eq(3).sum()
            count_others_other = other_df['common_sentiment_rating'].count() - count_negative_other

            # Construct contingency table
            contingency_table = [[count_negative_baidu, count_others_baidu], 
                                 [count_negative_other, count_others_other]]

            # Perform Chi-square test
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()
            chi2 = test_result.statistic
            p = test_result.pvalue

            # Store the results
            results[(baidu_engine, other_engine, category)] = {
                'chi2': chi2,
                'p-value': p
            }

    return results

# Comparing Baidu Template 1 with Google, Yahoo, and DuckDuckGo
comparison_results = compare_baidu_template_1(dfs)
comparison_results
# Out:
# {('Baidu Template 1', 'Google', 'Political'): {'chi2': 0.045351473922902605,
#   'p-value': 0.8313590554579958},
#  ('Baidu Template 1', 'Yahoo', 'Political'): {'chi2': 2.621011052978066,
#   'p-value': 0.10545722738902075},
#  ('Baidu Template 1', 'DuckDuckGo', 'Political'): {'chi2': 0.8997732426303856,
#   'p-value': 0.3428425204030051},
#  ('Baidu Template 1', 'Google', 'Nationalities'): {'chi2': 4.435288921497615,
#   'p-value': 0.03520326096510962},
#  ('Baidu Template 1', 'Yahoo', 'Nationalities'): {'chi2': 2.56107080506829,
#   'p-value': 0.10952437690649497},
#  ('Baidu Template 1',
#   'DuckDuckGo',
#   'Nationalities'): {'chi2': 15.781962605103512, 'p-value': 7.107690115060183e-05},
#  ('Baidu Template 1', 'Google', 'Peoples'): {'chi2': 2.6395320970488534,
#   'p-value': 0.10423423874507398},
#  ('Baidu Template 1', 'Yahoo', 'Peoples'): {'chi2': 0.10383712284271884,
#   'p-value': 0.7472726405847975},
#  ('Baidu Template 1', 'DuckDuckGo', 'Peoples'): {'chi2': 5.877170360897984,
#   'p-value': 0.015338452949432924},
#  ('Baidu Template 1', 'Google', 'Gender'): {'chi2': 0.001991806302476766,
#   'p-value': 0.9644025031718969},
#  ('Baidu Template 1', 'Yahoo', 'Gender'): {'chi2': 5.899988690862215,
#   'p-value': 0.015140982001210168},
#  ('Baidu Template 1', 'DuckDuckGo', 'Gender'): {'chi2': 4.190879449093904,
#   'p-value': 0.04064200863346401},
#  ('Baidu Template 1', 'Google', 'Age'): {'chi2': 0.8117845903793612,
#   'p-value': 0.36759316149393073},
#  ('Baidu Template 1', 'Yahoo', 'Age'): {'chi2': 0.8819140241909116,
#   'p-value': 0.34767797906383013},
#  ('Baidu Template 1', 'DuckDuckGo', 'Age'): {'chi2': 1.2061659659265092,
#   'p-value': 0.272092774007912},
#  ('Baidu Template 1', 'Google', 'Religion'): {'chi2': 0.1678321678321678,
#   'p-value': 0.6820456589350077},
#  ('Baidu Template 1', 'Yahoo', 'Religion'): {'chi2': 0.33811576354679795,
#   'p-value': 0.5609188633070814},
#  ('Baidu Template 1', 'DuckDuckGo', 'Religion'): {'chi2': 0.4125420875420876,
#   'p-value': 0.520682054029298},
#  ('Baidu Template 1', 'Google', 'Lifestyle'): {'chi2': 1.0582408043345546,
#   'p-value': 0.3036167598438345},
#  ('Baidu Template 1', 'Yahoo', 'Lifestyle'): {'chi2': 1.6158645276292338,
#   'p-value': 0.20366938567753057},
#  ('Baidu Template 1', 'DuckDuckGo', 'Lifestyle'): {'chi2': 4.444444444444445,
#   'p-value': 0.035014981019662494}}

# %%
import pandas as pd
import statsmodels.api as sm

# Load the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "DuckDuckGo": '../data/temp/modified_duckduckgo_follow_query.csv',
    "Google": '../data/temp/modified_google_follow_query.csv',
    "Yahoo": '../data/temp/modified_yahoo_follow_query.csv'
}

dfs = {}

# Process each file
for engine, path in file_paths.items():
    df = pd.read_csv(path)
    df['common_sentiment_rating'] = pd.to_numeric(df['common_sentiment_rating'], errors='coerce')
    dfs[engine] = df

def compare_baidu_template_1(dfs):
    baidu_engine = "Baidu Template 1"
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    results = []
    categories = set(dfs[baidu_engine]['category'].dropna())

    for category in categories:
        baidu_df = dfs[baidu_engine][dfs[baidu_engine]['category'] == category]
        for other_engine in other_engines:
            other_df = dfs[other_engine][dfs[other_engine]['category'] == category]

            # Count negative sentiment and others
            count_negative_baidu = baidu_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_df['common_sentiment_rating'].count() - count_negative_baidu
            count_negative_other = other_df['common_sentiment_rating'].eq(3).sum()
            count_others_other = other_df['common_sentiment_rating'].count() - count_negative_other

            # Construct contingency table and perform Chi-square test
            contingency_table = [[count_negative_baidu, count_others_baidu], [count_negative_other, count_others_other]]
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()

            # Store the results in a list of dictionaries
            results.append({
                'Baidu Engine': baidu_engine,
                'Other Engine': other_engine,
                'Category': category,
                'Chi-Square': test_result.statistic,
                'P-Value': test_result.pvalue
            })

    return pd.DataFrame(results)

# Comparing Baidu Template 1 with other engines
comparison_results_df = compare_baidu_template_1(dfs)

# Displaying the results in a DataFrame
print(comparison_results_df)
# Out:
#         Baidu Engine Other Engine       Category  Chi-Square   P-Value
# 0   Baidu Template 1       Google      Political    0.045351  0.831359
# 1   Baidu Template 1        Yahoo      Political    2.621011  0.105457
# 2   Baidu Template 1   DuckDuckGo      Political    0.899773  0.342843
# 3   Baidu Template 1       Google  Nationalities    4.435289  0.035203
# 4   Baidu Template 1        Yahoo  Nationalities    2.561071  0.109524
# 5   Baidu Template 1   DuckDuckGo  Nationalities   15.781963  0.000071
# 6   Baidu Template 1       Google        Peoples    2.639532  0.104234
# 7   Baidu Template 1        Yahoo        Peoples    0.103837  0.747273
# 8   Baidu Template 1   DuckDuckGo        Peoples    5.877170  0.015338
# 9   Baidu Template 1       Google         Gender    0.001992  0.964403
# 10  Baidu Template 1        Yahoo         Gender    5.899989  0.015141
# 11  Baidu Template 1   DuckDuckGo         Gender    4.190879  0.040642
# 12  Baidu Template 1       Google            Age    0.811785  0.367593
# 13  Baidu Template 1        Yahoo            Age    0.881914  0.347678
# 14  Baidu Template 1   DuckDuckGo            Age    1.206166  0.272093
# 15  Baidu Template 1       Google       Religion    0.167832  0.682046
# 16  Baidu Template 1        Yahoo       Religion    0.338116  0.560919
# 17  Baidu Template 1   DuckDuckGo       Religion    0.412542  0.520682
# 18  Baidu Template 1       Google      Lifestyle    1.058241  0.303617
# 19  Baidu Template 1        Yahoo      Lifestyle    1.615865  0.203669
# 20  Baidu Template 1   DuckDuckGo      Lifestyle    4.444444  0.035015

# %%
import pandas as pd
import statsmodels.api as sm

# Load the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "DuckDuckGo": '../data/temp/modified_duckduckgo_follow_query.csv',
    "Google": '../data/temp/modified_google_follow_query.csv',
    "Yahoo": '../data/temp/modified_yahoo_follow_query.csv'
}

dfs = {}

# Process each file
for engine, path in file_paths.items():
    df = pd.read_csv(path)
    df['common_sentiment_rating'] = pd.to_numeric(df['common_sentiment_rating'], errors='coerce')
    dfs[engine] = df

def compare_baidu_template(dfs, baidu_engine):
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    results = []
    categories = set(dfs[baidu_engine]['category'].dropna())

    for category in categories:
        baidu_df = dfs[baidu_engine][dfs[baidu_engine]['category'] == category]
        for other_engine in other_engines:
            other_df = dfs[other_engine][dfs[other_engine]['category'] == category]

            # Count negative sentiment and others
            count_negative_baidu = baidu_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_df['common_sentiment_rating'].count() - count_negative_baidu
            count_negative_other = other_df['common_sentiment_rating'].eq(3).sum()
            count_others_other = other_df['common_sentiment_rating'].count() - count_negative_other

            # Construct contingency table and perform Chi-square test
            contingency_table = [[count_negative_baidu, count_others_baidu], [count_negative_other, count_others_other]]
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()

            # Store the results in a list of dictionaries
            results.append({
                'Baidu Engine': baidu_engine,
                'Other Engine': other_engine,
                'Category': category,
                'Chi-Square': test_result.statistic,
                'P-Value': test_result.pvalue
            })

    return pd.DataFrame(results)

# Comparing Baidu Template 1 with other engines
comparison_results_df_template1 = compare_baidu_template(dfs, "Baidu Template 1")
print(comparison_results_df_template1)

# Comparing Baidu Template 2 with other engines
comparison_results_df_template2 = compare_baidu_template(dfs, "Baidu Template 2")
print(comparison_results_df_template2)
# Out:
#         Baidu Engine Other Engine       Category  Chi-Square   P-Value
# 0   Baidu Template 1       Google      Political    0.045351  0.831359
# 1   Baidu Template 1        Yahoo      Political    2.621011  0.105457
# 2   Baidu Template 1   DuckDuckGo      Political    0.899773  0.342843
# 3   Baidu Template 1       Google  Nationalities    4.435289  0.035203
# 4   Baidu Template 1        Yahoo  Nationalities    2.561071  0.109524
# 5   Baidu Template 1   DuckDuckGo  Nationalities   15.781963  0.000071
# 6   Baidu Template 1       Google        Peoples    2.639532  0.104234
# 7   Baidu Template 1        Yahoo        Peoples    0.103837  0.747273
# 8   Baidu Template 1   DuckDuckGo        Peoples    5.877170  0.015338
# 9   Baidu Template 1       Google         Gender    0.001992  0.964403
# 10  Baidu Template 1        Yahoo         Gender    5.899989  0.015141
# 11  Baidu Template 1   DuckDuckGo         Gender    4.190879  0.040642
# 12  Baidu Template 1       Google            Age    0.811785  0.367593
# 13  Baidu Template 1        Yahoo            Age    0.881914  0.347678
# 14  Baidu Template 1   DuckDuckGo            Age    1.206166  0.272093
# 15  Baidu Template 1       Google       Religion    0.167832  0.682046
# 16  Baidu Template 1        Yahoo       Religion    0.338116  0.560919
# 17  Baidu Template 1   DuckDuckGo       Religion    0.412542  0.520682
# 18  Baidu Template 1       Google      Lifestyle    1.058241  0.303617
# 19  Baidu Template 1        Yahoo      Lifestyle    1.615865  0.203669
# 20  Baidu Template 1   DuckDuckGo      Lifestyle    4.444444  0.035015
#         Baidu Engine Other Engine       Category  Chi-Square       P-Value
# 0   Baidu Template 2       Google      Political    0.423280  5.153047e-01
# 1   Baidu Template 2        Yahoo      Political    7.827774  5.144943e-03
# 2   Baidu Template 2   DuckDuckGo      Political    0.145202  7.031633e-01
# 3   Baidu Template 2       Google  Nationalities   13.315932  2.631605e-04
# 4   Baidu Template 2        Yahoo  Nationalities    8.095080  4.438559e-03
# 5   Baidu Template 2   DuckDuckGo  Nationalities   27.610883  1.483418e-07
# 6   Baidu Template 2       Google        Peoples    1.265351  2.606406e-01
# 7   Baidu Template 2        Yahoo        Peoples    0.082415  7.740507e-01
# 8   Baidu Template 2   DuckDuckGo        Peoples    4.769802  2.896316e-02
# 9   Baidu Template 2       Google         Gender    0.208524  6.479264e-01
# 10  Baidu Template 2        Yahoo         Gender    3.904673  4.815200e-02
# 11  Baidu Template 2   DuckDuckGo         Gender    2.759109  9.670205e-02
# 12  Baidu Template 2       Google            Age    0.578880  4.467515e-01
# 13  Baidu Template 2        Yahoo            Age    0.634067  4.258673e-01
# 14  Baidu Template 2   DuckDuckGo            Age    0.946740  3.305505e-01
# 15  Baidu Template 2       Google       Religion    0.107692  7.427869e-01
# 16  Baidu Template 2        Yahoo       Religion    0.124984  7.236911e-01
# 17  Baidu Template 2   DuckDuckGo       Religion    1.137317  2.862199e-01
# 18  Baidu Template 2       Google      Lifestyle    0.061071  8.048104e-01
# 19  Baidu Template 2        Yahoo      Lifestyle    0.381818  5.366318e-01
# 20  Baidu Template 2   DuckDuckGo      Lifestyle    2.696287  1.005822e-01

# %%
import  pandas as pd
baidu_1 = pd.read_csv('../data/temp/modified_baidu_follow_query_template_1.csv')
baidu_1.columns
# Out:
# Index(['query', 'suggestion', 'category', 'group', 'completion',
#        'suggestion_starts_with_query', 'extracted_suggestion',
#        'suggestion_follows_query', 'sentiment_rating_completion',
#        'sentiment_rating_full_suggestion', 'English',
#        'common_sentiment_rating'],
#       dtype='object')

# %%
import pandas as pd
import statsmodels.api as sm

# Load the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "DuckDuckGo": '../data/temp/modified_duckduckgo_follow_query.csv',
    "Google": '../data/temp/modified_google_follow_query.csv',
    "Yahoo": '../data/temp/modified_yahoo_follow_query.csv'
}

dfs = {}

# Process each file
for engine, path in file_paths.items():
    df = pd.read_csv(path)
    df['sentiment_rating_full_suggestion'] = pd.to_numeric(df['sentiment_rating_full_suggestion'], errors='coerce')
    dfs[engine] = df

def compare_baidu_template(dfs, baidu_engine):
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    results = []
    categories = set(dfs[baidu_engine]['category'].dropna())

    for category in categories:
        baidu_df = dfs[baidu_engine][dfs[baidu_engine]['category'] == category]
        for other_engine in other_engines:
            other_df = dfs[other_engine][dfs[other_engine]['category'] == category]

            # Count negative sentiment and others
            count_negative_baidu = baidu_df['sentiment_rating_full_suggestion'].eq(3).sum()
            count_others_baidu = baidu_df['sentiment_rating_full_suggestion'].count() - count_negative_baidu
            count_negative_other = other_df['sentiment_rating_full_suggestion'].eq(3).sum()
            count_others_other = other_df['sentiment_rating_full_suggestion'].count() - count_negative_other

            # Construct contingency table and perform Chi-square test
            contingency_table = [[count_negative_baidu, count_others_baidu], [count_negative_other, count_others_other]]
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()

            # Store the results in a list of dictionaries
            results.append({
                'Baidu Engine': baidu_engine,
                'Other Engine': other_engine,
                'Category': category,
                'Chi-Square': test_result.statistic,
                'P-Value': test_result.pvalue
            })

    return pd.DataFrame(results)

# Comparing Baidu Template 1 with other engines
comparison_results_df_template1 = compare_baidu_template(dfs, "Baidu Template 1")
print(comparison_results_df_template1)

# Comparing Baidu Template 2 with other engines
comparison_results_df_template2 = compare_baidu_template(dfs, "Baidu Template 2")
print(comparison_results_df_template2)
# Out:
#         Baidu Engine Other Engine       Category  Chi-Square       P-Value
# 0   Baidu Template 1       Google      Political    1.632653  2.013365e-01
# 1   Baidu Template 1        Yahoo      Political    1.152517  2.830229e-01
# 2   Baidu Template 1   DuckDuckGo      Political    1.448111  2.288313e-01
# 3   Baidu Template 1       Google  Nationalities   12.544569  3.973595e-04
# 4   Baidu Template 1        Yahoo  Nationalities    1.087658  2.969907e-01
# 5   Baidu Template 1   DuckDuckGo  Nationalities   31.228648  2.293562e-08
# 6   Baidu Template 1       Google        Peoples    4.498980  3.391509e-02
# 7   Baidu Template 1        Yahoo        Peoples    1.418981  2.335711e-01
# 8   Baidu Template 1   DuckDuckGo        Peoples   10.118467  1.467911e-03
# 9   Baidu Template 1       Google         Gender    0.322460  5.701330e-01
# 10  Baidu Template 1        Yahoo         Gender    5.318183  2.110401e-02
# 11  Baidu Template 1   DuckDuckGo         Gender   11.254656  7.942353e-04
# 12  Baidu Template 1       Google            Age    1.147541  2.840645e-01
# 13  Baidu Template 1        Yahoo            Age    3.058779  8.030201e-02
# 14  Baidu Template 1   DuckDuckGo            Age    6.513190  1.070772e-02
# 15  Baidu Template 1       Google       Religion    2.561364  1.095041e-01
# 16  Baidu Template 1        Yahoo       Religion    2.179663  1.398451e-01
# 17  Baidu Template 1   DuckDuckGo       Religion    3.733493  5.333176e-02
# 18  Baidu Template 1       Google      Lifestyle    7.880395  4.997357e-03
# 19  Baidu Template 1        Yahoo      Lifestyle    9.356794  2.221604e-03
# 20  Baidu Template 1   DuckDuckGo      Lifestyle   14.898700  1.134411e-04
#         Baidu Engine Other Engine       Category  Chi-Square       P-Value
# 0   Baidu Template 2       Google      Political    3.738541  5.317086e-02
# 1   Baidu Template 2        Yahoo      Political    0.118972  7.301518e-01
# 2   Baidu Template 2   DuckDuckGo      Political    3.694733  5.458452e-02
# 3   Baidu Template 2       Google  Nationalities   41.280926  1.318492e-10
# 4   Baidu Template 2        Yahoo  Nationalities   11.798957  5.926391e-04
# 5   Baidu Template 2   DuckDuckGo  Nationalities   64.620320  8.881784e-16
# 6   Baidu Template 2       Google        Peoples    6.618679  1.009146e-02
# 7   Baidu Template 2        Yahoo        Peoples    2.902596  8.843701e-02
# 8   Baidu Template 2   DuckDuckGo        Peoples   12.300804  4.527632e-04
# 9   Baidu Template 2       Google         Gender    0.089388  7.649566e-01
# 10  Baidu Template 2        Yahoo         Gender    4.131927  4.208141e-02
# 11  Baidu Template 2   DuckDuckGo         Gender    9.650058  1.893456e-03
# 12  Baidu Template 2       Google            Age    1.953662  1.621928e-01
# 13  Baidu Template 2        Yahoo            Age    4.570049  3.253563e-02
# 14  Baidu Template 2   DuckDuckGo            Age    8.871270  2.896935e-03
# 15  Baidu Template 2       Google       Religion    1.963141  1.611778e-01
# 16  Baidu Template 2        Yahoo       Religion    1.570301  2.101633e-01
# 17  Baidu Template 2   DuckDuckGo       Religion    3.109084  7.785672e-02
# 18  Baidu Template 2       Google      Lifestyle    7.317592  6.828283e-03
# 19  Baidu Template 2        Yahoo      Lifestyle    8.762255  3.075286e-03
# 20  Baidu Template 2   DuckDuckGo      Lifestyle   14.279230  1.575942e-04

# %%
import pandas as pd
import statsmodels.api as sm

# Load the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "DuckDuckGo": '../data/temp/modified_duckduckgo_follow_query.csv',
    "Google": '../data/temp/modified_google_follow_query.csv',
    "Yahoo": '../data/temp/modified_yahoo_follow_query.csv'
}

# Load the datasets
dfs = {}
for engine, path in file_paths.items():
    df = pd.read_csv(path)
    # Convert 'common_sentiment_rating' to numeric, treating non-numeric as NaN
    df['common_sentiment_rating'] = pd.to_numeric(df['common_sentiment_rating'], errors='coerce')
    dfs[engine] = df

# Function to compare common groups and categories in Baidu templates with other search engines
def compare_common_groups(dfs):
    results = {}
    baidu_engines = ["Baidu Template 1", "Baidu Template 2"]
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    categories = set.intersection(*(set(df['category'].dropna()) for df in dfs.values()))
    common_groups = set.intersection(*(set(df['group'].dropna()) for df in dfs.values()))

    for group in common_groups:
        for category in categories:
            for baidu_engine in baidu_engines:
                baidu_df = dfs[baidu_engine][(dfs[baidu_engine]['group'] == group) & 
                                             (dfs[baidu_engine]['category'] == category)]

                for other_engine in other_engines:
                    other_df = dfs[other_engine][(dfs[other_engine]['group'] == group) & 
                                                 (dfs[other_engine]['category'] == category)]

                    # Count negative sentiment and others
                    count_negative_baidu = baidu_df['common_sentiment_rating'].eq(3).sum()
                    count_others_baidu = baidu_df['common_sentiment_rating'].count() - count_negative_baidu

                    count_negative_other = other_df['common_sentiment_rating'].eq(3).sum()
                    count_others_other = other_df['common_sentiment_rating'].count() - count_negative_other

                    # Construct contingency table
                    contingency_table = [[count_negative_baidu, count_others_baidu], 
                                         [count_negative_other, count_others_other]]

                    # Perform Chi-square test
                    test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()
                    chi2 = test_result.statistic
                    p = test_result.pvalue

                    # Store the results
                    results[(baidu_engine, other_engine, group, category)] = {
                        'chi2': chi2,
                        'p-value': p
                    }

    return results

# Comparing common groups and categories between Baidu Templates and other engines
comparison_results = compare_common_groups(dfs)

# Print or analyze the results as needed
for key, value in comparison_results.items():
    print(f"{key}: Chi-square = {value['chi2']}, P-value = {value['p-value']}")

# %%
import pandas as pd
import statsmodels.api as sm

file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "DuckDuckGo": '../data/temp/modified_duckduckgo_follow_query.csv',
    "Google": '../data/temp/modified_google_follow_query.csv',
    "Yahoo": '../data/temp/modified_yahoo_follow_query.csv'
}

# Loading the datasets into DataFrames
dfs = {engine: pd.read_csv(path) for engine, path in file_paths.items()}

# Combining Baidu Template 1 and 2 and removing duplicates based on 'group'
dfs["Combined Baidu"] = pd.concat([dfs["Baidu Template 1"], dfs["Baidu Template 2"]]).drop_duplicates(subset='group')

# Function to compare Combined Baidu with other search engines using Chi-square test
def compare_combined_baidu(dfs):
    baidu_engine = "Combined Baidu"
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    results = {}
    categories = set(dfs[baidu_engine]['category'].dropna())

    for category in categories:
        baidu_df = dfs[baidu_engine][dfs[baidu_engine]['category'] == category]

        for other_engine in other_engines:
            other_df = dfs[other_engine][dfs[other_engine]['category'] == category]

            # Count negative sentiment (common_sentiment_rating == 3) and others
            count_negative_baidu = baidu_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_df['common_sentiment_rating'].count() - count_negative_baidu

            count_negative_other = other_df['common_sentiment_rating'].eq(3).sum()
            count_others_other = other_df['common_sentiment_rating'].count() - count_negative_other

            # Construct contingency table
            contingency_table = [[count_negative_baidu, count_others_baidu], 
                                 [count_negative_other, count_others_other]]

            # Perform Chi-square test
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()
            chi2 = test_result.statistic
            p = test_result.pvalue

            # Store the results
            results[(baidu_engine, other_engine, category)] = {
                'chi2': chi2,
                'p-value': p
            }

    return results

# Comparing Combined Baidu with Google, Yahoo, and DuckDuckGo
comparison_results_combined_baidu = compare_combined_baidu(dfs)

# Displaying the comparison results
comparison_results_combined_baidu
# Out:
# {('Combined Baidu', 'Google', 'Political'): {'chi2': 0.27777777777777757,
#   'p-value': 0.598161452683528},
#  ('Combined Baidu', 'Yahoo', 'Political'): {'chi2': 4.704301075268818,
#   'p-value': 0.03008723326295426},
#  ('Combined Baidu', 'DuckDuckGo', 'Political'): {'chi2': 0.12222222222222222,
#   'p-value': 0.7266366971638503},
#  ('Combined Baidu', 'Google', 'Nationalities'): {'chi2': 4.914089824213251,
#   'p-value': 0.026638495010083973},
#  ('Combined Baidu', 'Yahoo', 'Nationalities'): {'chi2': 3.476263500052428,
#   'p-value': 0.06225516181341606},
#  ('Combined Baidu',
#   'DuckDuckGo',
#   'Nationalities'): {'chi2': 15.113830553066968, 'p-value': 0.00010121900630910563},
#  ('Combined Baidu', 'Google', 'Peoples'): {'chi2': 0.012878048780487785,
#   'p-value': 0.9096488363925204},
#  ('Combined Baidu', 'Yahoo', 'Peoples'): {'chi2': 0.9072907290729074,
#   'p-value': 0.3408342913912614},
#  ('Combined Baidu', 'DuckDuckGo', 'Peoples'): {'chi2': 2.1365319865319865,
#   'p-value': 0.14382671048754392},
#  ('Combined Baidu', 'Google', 'Gender'): {'chi2': 0.15964352049369318,
#   'p-value': 0.6894849309587944},
#  ('Combined Baidu', 'Yahoo', 'Gender'): {'chi2': 0.8917993373585489,
#   'p-value': 0.344990169956929},
#  ('Combined Baidu', 'DuckDuckGo', 'Gender'): {'chi2': 0.7982082866741325,
#   'p-value': 0.3716296027947782},
#  ('Combined Baidu', 'Google', 'Age'): {'chi2': 0.16121809225257488,
#   'p-value': 0.6880375162161758},
#  ('Combined Baidu', 'Yahoo', 'Age'): {'chi2': 0.15043228987501436,
#   'p-value': 0.6981225884923884},
#  ('Combined Baidu', 'DuckDuckGo', 'Age'): {'chi2': 0.2270080125073285,
#   'p-value': 0.6337512716865332},
#  ('Combined Baidu', 'Google', 'Religion'): {'chi2': 0.761904761904762,
#   'p-value': 0.38273308888522595},
#  ('Combined Baidu', 'Yahoo', 'Religion'): {'chi2': 1.002231481481481,
#   'p-value': 0.3167711564485606},
#  ('Combined Baidu', 'DuckDuckGo', 'Religion'): {'chi2': 0.02166666666666668,
#   'p-value': 0.8829773063503712},
#  ('Combined Baidu', 'Google', 'Lifestyle'): {'chi2': 0.5714285714285714,
#   'p-value': 0.4496917979688908},
#  ('Combined Baidu', 'Yahoo', 'Lifestyle'): {'chi2': 0.15117235705470994,
#   'p-value': 0.6974175200972601},
#  ('Combined Baidu', 'DuckDuckGo', 'Lifestyle'): {'chi2': 0.47615740740740725,
#   'p-value': 0.4901680280687787}}

# %%
# Updating the function to compare the combined Baidu dataset with other search engines

def compare_combined_baidu(dfs, baidu_engine):
    other_engines = ["Google", "Yahoo", "DuckDuckGo"]
    results = []
    categories = set(dfs[baidu_engine]['category'].dropna())

    for category in categories:
        baidu_df = dfs[baidu_engine][dfs[baidu_engine]['category'] == category]
        for other_engine in other_engines:
            other_df = dfs[other_engine][dfs[other_engine]['category'] == category]

            # Count negative sentiment and others
            count_negative_baidu = baidu_df['sentiment_rating_full_suggestion'].eq(3).sum()
            count_others_baidu = baidu_df['sentiment_rating_full_suggestion'].count() - count_negative_baidu
            count_negative_other = other_df['sentiment_rating_full_suggestion'].eq(3).sum()
            count_others_other = other_df['sentiment_rating_full_suggestion'].count() - count_negative_other

            # Construct contingency table and perform Chi-square test
            contingency_table = [[count_negative_baidu, count_others_baidu], [count_negative_other, count_others_other]]
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()

            # Store the results in a list of dictionaries
            results.append({
                'Baidu Engine': baidu_engine,
                'Other Engine': other_engine,
                'Category': category,
                'Chi-Square': test_result.statistic,
                'P-Value': test_result.pvalue
            })

    return pd.DataFrame(results)

# Combining Baidu Template 1 and 2 and removing duplicates based on 'group'
combined_baidu = pd.concat([dfs["Baidu Template 1"], dfs["Baidu Template 2"]]).drop_duplicates(subset='group')
dfs["Combined Baidu"] = combined_baidu

# Comparing Combined Baidu with other search engines
comparison_results_df_combined_baidu = compare_combined_baidu(dfs, "Combined Baidu")
comparison_results_df_combined_baidu
# Out:
#       Baidu Engine Other Engine       Category  Chi-Square       P-Value
# 0   Combined Baidu       Google      Political    1.750000  1.858767e-01
# 1   Combined Baidu        Yahoo      Political    1.322449  2.501530e-01
# 2   Combined Baidu   DuckDuckGo      Political    0.400000  5.270893e-01
# 3   Combined Baidu       Google  Nationalities   11.761496  6.046861e-04
# 4   Combined Baidu        Yahoo  Nationalities    0.102776  7.485233e-01
# 5   Combined Baidu   DuckDuckGo  Nationalities    0.139635  7.086442e-01
# 6   Combined Baidu       Google        Peoples    9.652643  1.890794e-03
# 7   Combined Baidu        Yahoo        Peoples    1.750337  1.858344e-01
# 8   Combined Baidu   DuckDuckGo        Peoples    0.048953  8.248947e-01
# 9   Combined Baidu       Google         Gender   36.624410  1.432269e-09
# 10  Combined Baidu        Yahoo         Gender    0.647249  4.210979e-01
# 11  Combined Baidu   DuckDuckGo         Gender    0.214812  6.430216e-01
# 12  Combined Baidu       Google            Age   13.073332  2.995299e-04
# 13  Combined Baidu        Yahoo            Age    2.172026  1.405410e-01
# 14  Combined Baidu   DuckDuckGo            Age    1.540317  2.145706e-01
# 15  Combined Baidu       Google       Religion    2.073077  1.499188e-01
# 16  Combined Baidu        Yahoo       Religion    2.094391  1.478406e-01
# 17  Combined Baidu   DuckDuckGo       Religion    0.103704  7.474295e-01
# 18  Combined Baidu       Google      Lifestyle    8.318960  3.923338e-03
# 19  Combined Baidu        Yahoo      Lifestyle    0.264749  6.068758e-01
# 20  Combined Baidu   DuckDuckGo      Lifestyle    0.003278  9.543424e-01

# %%
import pandas as pd
import statsmodels.api as sm

# Paths to the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "Google": '../data/temp/modified_google_follow_query.csv'
}

# Loading the datasets into DataFrames
dfs = {engine: pd.read_csv(path) for engine, path in file_paths.items()}

# Combining Baidu Template 1 and 2 and removing duplicates based on 'group'
combined_baidu = pd.concat([dfs["Baidu Template 1"], dfs["Baidu Template 2"]]).drop_duplicates(subset='group')

# Loading the Google dataset
google = dfs["Google"]

# Identify common groups
common_groups = set(combined_baidu['English']).intersection(set(google['group']))

# Filter each dataset for common groups
combined_baidu_common = combined_baidu[combined_baidu['English'].isin(common_groups)]
google_common = google[google['group'].isin(common_groups)]

# Function to perform Chi-square test for each common group in each category
def compare_common_groups(baidu_df, google_df):
    results = {}
    categories = set(baidu_df['category'].dropna())

    for category in categories:
        baidu_category_df = baidu_df[baidu_df['category'] == category]
        google_category_df = google_df[google_df['category'] == category]

        for group in common_groups:
            baidu_group_df = baidu_category_df[baidu_category_df['group'] == group]
            google_group_df = google_category_df[google_category_df['group'] == group]

            # Count negative sentiment (common_sentiment_rating == 3) and others
            count_negative_baidu = baidu_group_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_group_df['common_sentiment_rating'].count() - count_negative_baidu

            count_negative_google = google_group_df['common_sentiment_rating'].eq(3).sum()
            count_others_google = google_group_df['common_sentiment_rating'].count() - count_negative_google

            # Construct contingency table
            contingency_table = [[count_negative_baidu, count_others_baidu], 
                                 [count_negative_google, count_others_google]]

            # Perform Chi-square test
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()
            chi2 = test_result.statistic
            p = test_result.pvalue

            # Store the results
            results[(category, group)] = {
                'chi2': chi2,
                'p-value': p
            }

    return results

# Compare common groups between Baidu and Google
comparison_results = compare_common_groups(combined_baidu_common, google_common)
comparison_results
# Out:
# {('Political', 'stepfathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Swedes'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'punks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'old people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Europeans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'brothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'celebrities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'mothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Syrians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'stepmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'nerds'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'immigrants'): {'chi2': 0.03428571428571428,
#   'p-value': 0.8531003889790089},
#  ('Political', 'Moroccans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Norwegians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Colombians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'wives'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'males'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Nigerians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Australians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Italians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'husbands'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Russians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'capitalists'): {'chi2': 0.06944444444444439,
#   'p-value': 0.7921473917958973},
#  ('Political', 'Americans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'children'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'fathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'kids'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Koreans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Finns'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'girlfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Dutch people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'grandmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Germans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'girls'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'women'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'teenagers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Asians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Jews'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'Black people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'boyfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'South Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'females'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Political', 'criminals'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'stepfathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Swedes'): {'chi2': 0.4937142857142857,
#   'p-value': 0.48227510850450095},
#  ('Nationalities', 'punks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'old people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Europeans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'brothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'celebrities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'mothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Syrians'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('Nationalities', 'stepmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'nerds'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'immigrants'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Moroccans'): {'chi2': 0.10370370370370367,
#   'p-value': 0.7474295171209488},
#  ('Nationalities', 'Norwegians'): {'chi2': 2.0720306513409965,
#   'p-value': 0.15002165543667023},
#  ('Nationalities', 'Colombians'): {'chi2': 0.10370370370370367,
#   'p-value': 0.7474295171209488},
#  ('Nationalities', 'wives'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'males'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Nigerians'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Nationalities', 'Australians'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Nationalities', 'Italians'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Nationalities', 'husbands'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Russians'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('Nationalities', 'capitalists'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Americans'): {'chi2': 0.018140589569160998,
#   'p-value': 0.8928593473274836},
#  ('Nationalities', 'Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'children'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'fathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'kids'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Koreans'): {'chi2': 0.5656565656565656,
#   'p-value': 0.45199006220295623},
#  ('Nationalities', 'Finns'): {'chi2': 0.7585284280936454,
#   'p-value': 0.38378943998707704},
#  ('Nationalities', 'girlfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Dutch people'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Nationalities', 'grandmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Germans'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('Nationalities', 'girls'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'women'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'teenagers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Asians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Jews'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'Black people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'boyfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'South Africans'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Nationalities', 'females'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Nationalities', 'criminals'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'stepfathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Swedes'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'punks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'old people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Europeans'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Peoples', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'brothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'celebrities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'mothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Syrians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'stepmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'nerds'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'immigrants'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Moroccans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Norwegians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Colombians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'wives'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'males'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Nigerians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Australians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Italians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'husbands'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Russians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'capitalists'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Americans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Africans'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('Peoples', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'children'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'fathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'kids'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Koreans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Finns'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'girlfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Dutch people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'grandmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Germans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'girls'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'women'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'teenagers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Asians'): {'chi2': 0.8317901234567899,
#   'p-value': 0.3617554064234162},
#  ('Peoples', 'Jews'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'Black people'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Peoples', 'boyfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'South Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'females'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Peoples', 'criminals'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'stepfathers'): {'chi2': 0.06944444444444439,
#   'p-value': 0.7921473917958973},
#  ('Gender', 'Swedes'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'punks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'old people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Europeans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'brothers'): {'chi2': 0.16761904761904758,
#   'p-value': 0.682236562435615},
#  ('Gender', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'celebrities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'mothers'): {'chi2': 0.25249597423510467,
#   'p-value': 0.6153230429550354},
#  ('Gender', 'Syrians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'stepmothers'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('Gender', 'nerds'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'immigrants'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Moroccans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Norwegians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Colombians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'wives'): {'chi2': 1.3424556213017758,
#   'p-value': 0.24660137831119078},
#  ('Gender', 'males'): {'chi2': 0.2380952380952381,
#   'p-value': 0.6255852315243251},
#  ('Gender', 'Nigerians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Australians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Italians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'husbands'): {'chi2': 0.9000000000000001,
#   'p-value': 0.34278171114791134},
#  ('Gender', 'Russians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'capitalists'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Americans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'children'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'fathers'): {'chi2': 0.29323308270676685,
#   'p-value': 0.5881561052471502},
#  ('Gender', 'kids'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Koreans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Finns'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'girlfriends'): {'chi2': 0.9000000000000001,
#   'p-value': 0.34278171114791134},
#  ('Gender', 'Dutch people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'grandmothers'): {'chi2': 0.0888888888888889,
#   'p-value': 0.7655944839957641},
#  ('Gender', 'Germans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'girls'): {'chi2': 0.018140589569160998,
#   'p-value': 0.8928593473274836},
#  ('Gender', 'women'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('Gender', 'teenagers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Asians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Jews'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'Black people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'boyfriends'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('Gender', 'South Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Gender', 'females'): {'chi2': 0.004183006535947712,
#   'p-value': 0.9484318393195734},
#  ('Gender', 'criminals'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'stepfathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Swedes'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'punks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'old people'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('Age', 'Europeans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'brothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'celebrities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'mothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Syrians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'stepmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'nerds'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'immigrants'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Moroccans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Norwegians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Colombians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'wives'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'males'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Nigerians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Australians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Italians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'husbands'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Russians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'capitalists'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Americans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'children'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Age', 'fathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'kids'): {'chi2': 0.018140589569160998,
#   'p-value': 0.8928593473274836},
#  ('Age', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Koreans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Finns'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'girlfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Dutch people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'grandmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Germans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'girls'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'women'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'teenagers'): {'chi2': 0.06944444444444439,
#   'p-value': 0.7921473917958973},
#  ('Age', 'Asians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Jews'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'Black people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'boyfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'South Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'females'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Age', 'criminals'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'stepfathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Swedes'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'punks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'old people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Europeans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'brothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'celebrities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'mothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Syrians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'stepmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'nerds'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'immigrants'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Moroccans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Norwegians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Colombians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'wives'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'males'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Nigerians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Australians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Italians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'husbands'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Russians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'capitalists'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Americans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'children'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'fathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'kids'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Koreans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Finns'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'girlfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Dutch people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'grandmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Germans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'girls'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'women'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'teenagers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Asians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'Jews'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Religion', 'Black people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'boyfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'South Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'females'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Religion', 'criminals'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'stepfathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Swedes'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'punks'): {'chi2': 0.0888888888888889,
#   'p-value': 0.7655944839957641},
#  ('Lifestyle', 'old people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Europeans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Indians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'brothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Scots'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'celebrities'): {'chi2': 0.004183006535947711,
#   'p-value': 0.9484318393195734},
#  ('Lifestyle', 'mothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Syrians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'stepmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'nerds'): {'chi2': 0.004183006535947712,
#   'p-value': 0.9484318393195734},
#  ('Lifestyle', 'immigrants'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Moroccans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Norwegians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Colombians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'wives'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'males'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Nigerians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Australians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Italians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'husbands'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Russians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'capitalists'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Americans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'men'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'children'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'fathers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'kids'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'geeks'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Koreans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Finns'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'girlfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Dutch people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'grandmothers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Germans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'girls'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'women'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'teenagers'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Asians'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Jews'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'Black people'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'boyfriends'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'South Africans'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'females'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Lifestyle', 'criminals'): {'chi2': 0.0, 'p-value': 1.0}}

# %%
import pandas as pd
import statsmodels.api as sm

# Paths to the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "Google": '../data/temp/modified_google_follow_query.csv'
}

# Loading the datasets into DataFrames
dfs = {engine: pd.read_csv(path) for engine, path in file_paths.items()}

# Combining Baidu Template 1 and 2 and removing duplicates based on 'group'
combined_baidu = pd.concat([dfs["Baidu Template 1"], dfs["Baidu Template 2"]]).drop_duplicates(subset='group')

# Loading the Google dataset
google = dfs["Google"]

# Identify common groups
common_groups = set(combined_baidu['English']).intersection(set(google['group']))

# Filter each dataset for common groups
combined_baidu_common = combined_baidu[combined_baidu['English'].isin(common_groups)]
google_common = google[google['group'].isin(common_groups)]

# Function to perform Chi-square test for each category in each common group
def compare_categories_in_common_groups(baidu_df, google_df):
    results = {}
    for group in common_groups:
        baidu_group_df = baidu_df[baidu_df['group'] == group]
        google_group_df = google_df[google_df['group'] == group]

        categories = set(baidu_group_df['category']).union(set(google_group_df['category']))

        for category in categories:
            baidu_category_df = baidu_group_df[baidu_group_df['category'] == category]
            google_category_df = google_group_df[google_group_df['category'] == category]

            # Count negative sentiment (common_sentiment_rating == 3) and others
            count_negative_baidu = baidu_category_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_category_df['common_sentiment_rating'].count() - count_negative_baidu

            count_negative_google = google_category_df['common_sentiment_rating'].eq(3).sum()
            count_others_google = google_category_df['common_sentiment_rating'].count() - count_negative_google

            # Construct contingency table
            contingency_table = [[count_negative_baidu, count_others_baidu], 
                                 [count_negative_google, count_others_google]]

            # Perform Chi-square test
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()
            chi2 = test_result.statistic
            p = test_result.pvalue

            # Store the results
            results[(group, category)] = {
                'chi2': chi2,
                'p-value': p
            }

    return results

# Compare categories within common groups between Baidu and Google
comparison_results = compare_categories_in_common_groups(combined_baidu_common, google_common)
comparison_results
# Out:
# {('stepfathers', 'Gender'): {'chi2': 0.06944444444444439,
#   'p-value': 0.7921473917958973},
#  ('Swedes', 'Nationalities'): {'chi2': 0.4937142857142857,
#   'p-value': 0.48227510850450095},
#  ('punks', 'Lifestyle'): {'chi2': 0.0888888888888889,
#   'p-value': 0.7655944839957641},
#  ('old people', 'Age'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('Europeans', 'Peoples'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Indians', 'Nationalities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('brothers', 'Gender'): {'chi2': 0.16761904761904758,
#   'p-value': 0.682236562435615},
#  ('Scots', 'Nationalities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('celebrities', 'Lifestyle'): {'chi2': 0.004183006535947711,
#   'p-value': 0.9484318393195734},
#  ('mothers', 'Gender'): {'chi2': 0.25249597423510467,
#   'p-value': 0.6153230429550354},
#  ('Syrians', 'Nationalities'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('stepmothers', 'Gender'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('nerds', 'Lifestyle'): {'chi2': 0.004183006535947712,
#   'p-value': 0.9484318393195734},
#  ('immigrants', 'Political'): {'chi2': 0.03428571428571428,
#   'p-value': 0.8531003889790089},
#  ('Moroccans', 'Nationalities'): {'chi2': 0.10370370370370367,
#   'p-value': 0.7474295171209488},
#  ('Norwegians', 'Nationalities'): {'chi2': 2.0720306513409965,
#   'p-value': 0.15002165543667023},
#  ('Colombians', 'Nationalities'): {'chi2': 0.10370370370370367,
#   'p-value': 0.7474295171209488},
#  ('wives', 'Gender'): {'chi2': 1.3424556213017758,
#   'p-value': 0.24660137831119078},
#  ('males', 'Gender'): {'chi2': 0.2380952380952381,
#   'p-value': 0.6255852315243251},
#  ('Nigerians', 'Nationalities'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Australians', 'Nationalities'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Italians', 'Nationalities'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('husbands', 'Gender'): {'chi2': 0.9000000000000001,
#   'p-value': 0.34278171114791134},
#  ('Russians', 'Nationalities'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('capitalists', 'Political'): {'chi2': 0.06944444444444439,
#   'p-value': 0.7921473917958973},
#  ('Americans', 'Nationalities'): {'chi2': 0.018140589569160998,
#   'p-value': 0.8928593473274836},
#  ('Africans', 'Peoples'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('men', 'Gender'): {'chi2': 0.0, 'p-value': 1.0},
#  ('children', 'Age'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('fathers', 'Gender'): {'chi2': 0.29323308270676685,
#   'p-value': 0.5881561052471502},
#  ('kids', 'Age'): {'chi2': 0.018140589569160998,
#   'p-value': 0.8928593473274836},
#  ('geeks', 'Lifestyle'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Koreans', 'Nationalities'): {'chi2': 0.5656565656565656,
#   'p-value': 0.45199006220295623},
#  ('Finns', 'Nationalities'): {'chi2': 0.7585284280936454,
#   'p-value': 0.38378943998707704},
#  ('girlfriends', 'Gender'): {'chi2': 0.9000000000000001,
#   'p-value': 0.34278171114791134},
#  ('Dutch people', 'Nationalities'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('grandmothers', 'Gender'): {'chi2': 0.0888888888888889,
#   'p-value': 0.7655944839957641},
#  ('Germans', 'Nationalities'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('girls', 'Gender'): {'chi2': 0.018140589569160998,
#   'p-value': 0.8928593473274836},
#  ('women', 'Gender'): {'chi2': 0.315, 'p-value': 0.574628070589583},
#  ('teenagers', 'Age'): {'chi2': 0.06944444444444439,
#   'p-value': 0.7921473917958973},
#  ('Asians', 'Peoples'): {'chi2': 0.8317901234567899,
#   'p-value': 0.3617554064234162},
#  ('Jews', 'Religion'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('Black people', 'Peoples'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('boyfriends', 'Gender'): {'chi2': 0.5739795918367346,
#   'p-value': 0.44868185197701504},
#  ('South Africans', 'Nationalities'): {'chi2': 0.0694444444444444,
#   'p-value': 0.7921473917958972},
#  ('females', 'Gender'): {'chi2': 0.004183006535947712,
#   'p-value': 0.9484318393195734},
#  ('criminals', 'Lifestyle'): {'chi2': 0.0, 'p-value': 1.0}}

# %%
import pandas as pd
import statsmodels.api as sm

# Paths to the datasets
file_paths = {
    "Baidu Template 1": '../data/temp/modified_baidu_follow_query_template_1.csv',
    "Baidu Template 2": '../data/temp/modified_baidu_follow_query_template_2.csv',
    "Google": '../data/temp/modified_google_follow_query.csv'
}

# Loading the datasets into DataFrames
dfs = {engine: pd.read_csv(path) for engine, path in file_paths.items()}

# Combining Baidu Template 1 and 2 and removing duplicates based on 'group'
combined_baidu = pd.concat([dfs["Baidu Template 1"], dfs["Baidu Template 2"]]).drop_duplicates(subset='group')

# Loading the Google dataset
google = dfs["Google"]

# Identify common groups
common_groups = set(combined_baidu['English']).intersection(set(google['group']))

# Filter each dataset for common groups
combined_baidu_common = combined_baidu[combined_baidu['English'].isin(common_groups)]
google_common = google[google['group'].isin(common_groups)]

# Function to perform Chi-square test for each category in each common group
def compare_categories_in_common_groups(baidu_df, google_df):
    results = {}
    for group in common_groups:
        baidu_group_df = baidu_df[baidu_df['English'] == group]
        google_group_df = google_df[google_df['group'] == group]

        categories = set(baidu_group_df['category']).union(set(google_group_df['category']))

        for category in categories:
            baidu_category_df = baidu_group_df[baidu_group_df['category'] == category]
            google_category_df = google_group_df[google_group_df['category'] == category]

            # Count negative sentiment (common_sentiment_rating == 3) and others
            count_negative_baidu = baidu_category_df['common_sentiment_rating'].eq(3).sum()
            count_others_baidu = baidu_category_df['common_sentiment_rating'].count() - count_negative_baidu

            count_negative_google = google_category_df['common_sentiment_rating'].eq(3).sum()
            count_others_google = google_category_df['common_sentiment_rating'].count() - count_negative_google

            # Construct contingency table
            contingency_table = [[count_negative_baidu, count_others_baidu], 
                                 [count_negative_google, count_others_google]]

            # Perform Chi-square test
            test_result = sm.stats.Table2x2(contingency_table).test_nominal_association()
            chi2 = test_result.statistic
            p = test_result.pvalue

            # Store the results
            results[(group, category)] = {
                'chi2': chi2,
                'p-value': p
            }

    return results

# Compare categories within common groups between Baidu and Google
comparison_results = compare_categories_in_common_groups(combined_baidu_common, google_common)
comparison_results
# Out:
# {('stepfathers', 'Gender'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Swedes', 'Nationalities'): {'chi2': 1.6170000000000002,
#   'p-value': 0.20351060264386134},
#  ('punks', 'Lifestyle'): {'chi2': 0.44999999999999996,
#   'p-value': 0.502334954360502},
#  ('old people', 'Age'): {'chi2': 0.8711111111111111,
#   'p-value': 0.3506478897044589},
#  ('Europeans', 'Peoples'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Indians', 'Nationalities'): {'chi2': 0.09722222222222228,
#   'p-value': 0.7551888894226784},
#  ('brothers', 'Gender'): {'chi2': 0.006845238095238094,
#   'p-value': 0.9340614956547423},
#  ('Scots', 'Nationalities'): {'chi2': 0.13392857142857145,
#   'p-value': 0.7143930376343262},
#  ('celebrities', 'Lifestyle'): {'chi2': 0.09777777777777788,
#   'p-value': 0.7545128626937243},
#  ('mothers', 'Gender'): {'chi2': 1.0330434782608695,
#   'p-value': 0.3094449125794545},
#  ('Syrians', 'Nationalities'): {'chi2': 1.3718820861678005,
#   'p-value': 0.24148877833190419},
#  ('stepmothers', 'Gender'): {'chi2': 0.0888888888888889,
#   'p-value': 0.7655944839957641},
#  ('nerds', 'Lifestyle'): {'chi2': 0.21838235294117653,
#   'p-value': 0.6402752580878343},
#  ('immigrants', 'Political'): {'chi2': 0.021666666666666678,
#   'p-value': 0.8829773063503712},
#  ('Moroccans', 'Nationalities'): {'chi2': 0.5555555555555555,
#   'p-value': 0.456056540250256},
#  ('Norwegians', 'Nationalities'): {'chi2': 4.608620689655172,
#   'p-value': 0.0318116105861036},
#  ('Colombians', 'Nationalities'): {'chi2': 0.5555555555555555,
#   'p-value': 0.456056540250256},
#  ('wives', 'Gender'): {'chi2': 0.7326007326007328,
#   'p-value': 0.39204148660378024},
#  ('males', 'Gender'): {'chi2': 0.8184523809523809,
#   'p-value': 0.36563304213519476},
#  ('Nigerians', 'Nationalities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Australians', 'Nationalities'): {'chi2': 0.3333333333333334,
#   'p-value': 0.563702861650773},
#  ('Italians', 'Nationalities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('husbands', 'Gender'): {'chi2': 0.412326388888889,
#   'p-value': 0.5207910777983107},
#  ('Russians', 'Nationalities'): {'chi2': 0.2380952380952381,
#   'p-value': 0.6255852315243251},
#  ('capitalists', 'Political'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Americans', 'Nationalities'): {'chi2': 0.2810846560846561,
#   'p-value': 0.5959911745014203},
#  ('Africans', 'Peoples'): {'chi2': 1.3718820861678005,
#   'p-value': 0.24148877833190419},
#  ('men', 'Gender'): {'chi2': 0.14520202020202028,
#   'p-value': 0.7031633068466783},
#  ('children', 'Age'): {'chi2': 0.3333333333333334,
#   'p-value': 0.563702861650773},
#  ('fathers', 'Gender'): {'chi2': 1.1101973684210524,
#   'p-value': 0.29203904905029665},
#  ('kids', 'Age'): {'chi2': 0.2810846560846561, 'p-value': 0.5959911745014203},
#  ('geeks', 'Lifestyle'): {'chi2': 0.09722222222222228,
#   'p-value': 0.7551888894226784},
#  ('Koreans', 'Nationalities'): {'chi2': 0.5656565656565656,
#   'p-value': 0.45199006220295623},
#  ('Finns', 'Nationalities'): {'chi2': 0.3036324786324788,
#   'p-value': 0.5816140936257692},
#  ('girlfriends', 'Gender'): {'chi2': 0.412326388888889,
#   'p-value': 0.5207910777983107},
#  ('Dutch people', 'Nationalities'): {'chi2': 0.0, 'p-value': 1.0},
#  ('grandmothers', 'Gender'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Germans', 'Nationalities'): {'chi2': 0.8711111111111111,
#   'p-value': 0.3506478897044589},
#  ('girls', 'Gender'): {'chi2': 0.04625850340136051,
#   'p-value': 0.8297065833456503},
#  ('women', 'Gender'): {'chi2': 0.8711111111111111,
#   'p-value': 0.3506478897044589},
#  ('teenagers', 'Age'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Asians', 'Peoples'): {'chi2': 1.851851851851852,
#   'p-value': 0.17356816655592155},
#  ('Jews', 'Religion'): {'chi2': 0.0, 'p-value': 1.0},
#  ('Black people', 'Peoples'): {'chi2': 0.0, 'p-value': 1.0},
#  ('boyfriends', 'Gender'): {'chi2': 1.3718820861678007,
#   'p-value': 0.24148877833190396},
#  ('South Africans', 'Nationalities'): {'chi2': 0.3333333333333334,
#   'p-value': 0.563702861650773},
#  ('females', 'Gender'): {'chi2': 0.21838235294117653,
#   'p-value': 0.6402752580878343},
#  ('criminals', 'Lifestyle'): {'chi2': 0.1222222222222222,
#   'p-value': 0.7266366971638503}}
