# %%
import  pandas as pd

baidu = pd.read_csv('data/baidu.csv')

# %%
baidu[baidu['group_English'] == 'schoolgirls']
# Out:
#         query     suggestion category group group_English     completion  \
# 498  为什么女学生这么  为什么现在的女学生这么好看   Gender   女学生   schoolgirls  为什么现在的女学生这么好看
# 499  为什么女学生这么    为什么美国大学女学生多   Gender   女学生   schoolgirls    为什么美国大学女学生多
# 500  为什么女学生这么     郑耀先为什么抓女学生   Gender   女学生   schoolgirls     郑耀先为什么抓女学生
# 501  为什么女学生这么     薛老为什么不收女学生   Gender   女学生   schoolgirls     薛老为什么不收女学生
# 502  为什么女学生这么     孔子为什么没有女学生   Gender   女学生   schoolgirls     孔子为什么没有女学生
# 503  为什么女学生这么  为什么老师对一女学生特别好   Gender   女学生   schoolgirls  为什么老师对一女学生特别好
# 504  为什么女学生这么    为什么女学生不能留长发   Gender   女学生   schoolgirls    为什么女学生不能留长发
# 505  为什么女学生这么   为什么现在的女学生都抽烟   Gender   女学生   schoolgirls   为什么现在的女学生都抽烟
# 506  为什么女学生这么    为什么女学生喜欢提裤子   Gender   女学生   schoolgirls    为什么女学生喜欢提裤子
# 507  为什么女学生这么     女学生为什么要剪短发   Gender   女学生   schoolgirls     女学生为什么要剪短发
# 508  女学生为什么这么     女学生为什么要剪短发   Gender   女学生   schoolgirls     女学生为什么要剪短发
# 509  女学生为什么这么     女学生为什么喜欢混混   Gender   女学生   schoolgirls     女学生为什么喜欢混混
# ...

# %%
import pandas as pd
google = pd.read_csv('data/google.csv')
google[google['sentiment_rating_completion'] == 'Neutral']
# Out:
#                       query                        suggestion  category  \
# 5        why are boomers so           why are boomers so rich       Age
# 10       why are boomers so           why are boomers so loud       Age
# 15          why are kids so              why are kids so loud       Age
# 33   why are millennials so  why are millennials so different       Age
# 34   why are millennials so  why are millennials so nostalgic       Age
# ..                      ...                               ...       ...
# 585      why are blondes so          why are blondes so crazy   Peoples
# 643  why are Protestants so     why are protestants so called  Religion
# 648    why are religions so      why are religions so similar  Religion
# 650    why are religions so    why are religions so different  Religion
# 651    why are religions so      why are religions so diverse  Religion
#
#            group                     completion suggestion_starts_with_query  \
# ...

# %%
google['sentiment_rating_completion'].value_counts()
# Out:
# sentiment_rating_completion
# Negative    197
# Neutral     104
# Positive     88
# Name: count, dtype: int64
